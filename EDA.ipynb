# %% [markdown]
# #Import libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #Import data set

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fd05461b-1379-44d4-b18f-1353f3814baf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fd05461b-1379-44d4-b18f-1353f3814baf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# #Read the data

# %%
df = pd.read_csv('cleaned_data.csv')

# %% [markdown]
# #Dataset overview

# %%
df
# Out:
#            Job Title  Rating  Average Salary State
# 0     data scientist     3.5           146.0    NY
# 1     data scientist     4.5           146.0    NY
# 2            analyst     3.4           146.0    NJ
# 3     data scientist     3.4           146.0    NY
# 4     data scientist     2.9           146.0    NY
# ...              ...     ...             ...   ...
# 4886           other     3.2            51.0    OH
# 4887           other     4.2            68.0    OH
# 4888           other     4.0            89.5    OH
# 4889         analyst     4.0            89.0    OH
# 4890         analyst     3.6            59.0    OH
#
# [4891 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4891 entries, 0 to 4890
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Job Title       4891 non-null   object
#  1   Rating          4891 non-null   float64
#  2   Average Salary  4891 non-null   float64
#  3   State           4891 non-null   object
# dtypes: float64(2), object(2)
# memory usage: 153.0+ KB

# %%
df.describe()
# Out:
#             Rating  Average Salary
# count  4891.000000     4891.000000
# mean      3.817011      106.082192
# std       0.577004       35.749097
# min       1.000000       37.500000
# 25%       3.500000       77.500000
# 50%       3.800000      102.000000
# 75%       4.100000      130.000000
# max       5.000000      268.000000

# %% [markdown]
# #Data Visualisation

# %%
sns.pairplot(df)

# %%
df['Average Salary'].hist(bins= 10)
# Out:
# <Axes: >

# %%
df['Rating'].hist(bins= 10)
# Out:
# <Axes: >

# %%
sns.displot(df['Rating'], bins = 10)

# %%
sns.boxplot(x='Rating', data=df)
# Out:
# <Axes: xlabel='Rating'>

# %%
sns.boxplot(x='Average Salary', data=df)
# Out:
# <Axes: xlabel='Average Salary'>

# %%
sns.countplot(x='Job Title', data= df, hue = 'Job Title')
plt.xticks(rotation= 45, ha='right')
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'data scientist'),
#   Text(1, 0, 'analyst'),
#   Text(2, 0, 'researcher'),
#   Text(3, 0, 'other'),
#   Text(4, 0, 'data engineer'),
#   Text(5, 0, 'manager'),
#   Text(6, 0, 'machine learning engineer'),
#   Text(7, 0, 'director'),
#   Text(8, 0, 'deep learning engineer')])

# %%
sns.scatterplot(x = 'Rating', y = 'Average Salary', data = df, hue = 'Job Title' )
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# %%
sns.scatterplot(x='State', y='Average Salary', data=df, hue='Job Title')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left') #to remove the legend > legend = False
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
data_scientist = df[df['Job Title'] == 'data scientist']

# %%
sns.scatterplot(x = 'Rating', y = 'Average Salary', data = data_scientist)
# Out:
# <Axes: xlabel='Rating', ylabel='Average Salary'>

# %%
ML_Engineer = df[df['Job Title'] == 'machine learning engineer']

# %%
sns.scatterplot(x = 'Rating', y = 'Average Salary', data = ML_Engineer )
# Out:
# <Axes: xlabel='Rating', ylabel='Average Salary'>

# %%
ny = df[df['State']== 'NY']

# %%
sns.scatterplot(x = 'Rating', y = 'Average Salary', data = ny)
# Out:
# <Axes: xlabel='Rating', ylabel='Average Salary'>

# %%
california = df[df['State']== 'CA']

# %%
sns.scatterplot(x = 'Rating', y = 'Average Salary', data = california)
# Out:
# <Axes: xlabel='Rating', ylabel='Average Salary'>
